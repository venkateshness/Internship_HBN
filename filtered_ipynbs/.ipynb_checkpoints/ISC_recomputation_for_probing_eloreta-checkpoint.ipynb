# %%
import numpy as np

#low_isc = np.load('S4B2/Generated_Data/low_isc_averaged_with_cov.npz')
#high_isc['high_isc_averaged'] low_isc
high_isc = np.load('S4B2/Generated_Data/high_isc_averaged_with_cov.npz')
plot = list() 
for m in range(360):
    hm = np.triu(np.corrcoef(np.array(high_isc['high_isc_averaged'])[:,m,:])) #high_isc['high_isc_averaged']

    iscs = list()
    for i in range(9):
        iscs.append(np.sum(hm[i][i+1:]))
    plot.append(sum(iscs)/ sum(np.arange(10)))

# %%
cd
# Out:
# /homes/v20subra

# %%
np.average(high_isc['high_isc_averaged'],0)[:,250]
# Out:
# (360,)

# %%
for m in range(1):
    iscs = list()
    tr = np.triu(tra)
    for i in range(9):
        
        iscs.append(np.sum(tr[i][i+1:]))
    print(iscs)
    print(sum(iscs)/ sum(np.arange(10)))
# Out:
# [45, 124, 182, 219, 235, 230, 204, 157, 89]
# 33.0

# %%
#np.savez('low_isc_averaged',low_isc = low_isc)
import matplotlib.pyplot as plt

from nilearn.regions import signals_to_img_labels  
# load nilearn label masker for inverse transform
from nilearn.input_data import NiftiLabelsMasker, NiftiMasker
from nilearn.datasets import fetch_icbm152_2009
from nilearn import image, plotting
from nilearn import datasets
from os.path import join as opj
import matplotlib.pyplot as plt

path_Glasser = 'S4B2/GSP/Glasser_masker.nii.gz'


mnitemp = fetch_icbm152_2009()
mask_mni=image.load_img(mnitemp['mask'])
glasser_atlas=image.load_img(path_Glasser)


#print(NiftiMasker.__doc__)

fig,ax = plt.subplots(nrows=1,ncols=1, figsize=(10,10))

signal=[]
U0_brain=[]
signal=np.expand_dims(np.array(np.average(high_isc['high_isc_averaged'],0)[:,250]), axis=0) # add dimension 1 to signal array
U0_brain = signals_to_img_labels(signal,path_Glasser,mnitemp['mask'])
plotting.plot_glass_brain(U0_brain,title='h ISC',colorbar=True,plot_abs=False,cmap='spring',display_mode='xz',figure=fig,axes=ax)
# Out:
# /homes/v20subra/.local/lib/python3.8/site-packages/nilearn/datasets/__init__.py:86: FutureWarning: Fetchers from the nilearn.datasets module will be updated in version 0.9 to return python strings instead of bytes and Pandas dataframes instead of Numpy arrays.
#   warn("Fetchers from the nilearn.datasets module will be "

# %%
#np.savez('low_isc_averaged',low_isc = low_isc)
import matplotlib.pyplot as plt

from nilearn.regions import signals_to_img_labels  
# load nilearn label masker for inverse transform
from nilearn.input_data import NiftiLabelsMasker, NiftiMasker
from nilearn.datasets import fetch_icbm152_2009
from nilearn import image, plotting
from nilearn import datasets
from os.path import join as opj
import matplotlib.pyplot as plt

path_Glasser = 'S4B2/GSP/Glasser_masker.nii.gz'


mnitemp = fetch_icbm152_2009()
mask_mni=image.load_img(mnitemp['mask'])
glasser_atlas=image.load_img(path_Glasser)


fig,ax = plt.subplots(nrows=1,ncols=1, figsize=(10,10))

signal=[]
U0_brain=[]
signal=np.expand_dims(np.array(plot), axis=0) # add dimension 1 to signal array
U0_brain = signals_to_img_labels(signal,path_Glasser,mnitemp['mask'])
plotting.plot_glass_brain(U0_brain,title='l ISC',colorbar=True,plot_abs=False,cmap='spring',display_mode='xz',figure=fig,axes=ax)

# %%
import seaborn as sns

# %%
def probe(vertices,data):

    plot = list()
    for m in tqdm.tqdm(range(vertices)):
        hm = np.triu(np.corrcoef(np.array(data)[:,m,:]))
        iscs = list()
        comp = [iscs.append(np.sum(hm[i][i+1:])) for i in range(9)]
        plot.append(sum(iscs)/ 45)
    return plot

# %% [markdown]
# ### 20k vertices

# %%
low_isc_20k = np.load('S4B2/Generated_Data/low_isc_wo_average.npz')['low_isc_wo_average']
high_isc_20k = np.load('S4B2/Generated_Data/high_isc_wo_average.npz')['high_isc_wo_average']

# %%
l = probe(20484,low_isc_20k)
# Out:
# 100%|██████████| 20484/20484 [1:53:59<00:00,  2.99it/s]

# %%
h = probe(20484,high_isc_20k)
# Out:
# 100%|██████████| 20484/20484 [1:50:13<00:00,  3.10it/s]

# %%
q = [ 23, 102, 103, 106, 123, 172, 173, 174, 203, 282, 286, 303, 352,
        353, 354]

# %%
#np.savez('S4B2/Generated_Data/high_isc_20k_correlation.npz',high_isc_20k_correlation = h)

# %%
from data import surface_plot
from imp import reload 
import numpy as np
reload(surface_plot)
h = np.load('S4B2/Generated_Data/high_isc_20k_correlation.npz')['high_isc_20k_correlation']


surface_plot.plot(np.array(h),'high ISC',None,None,None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      39     try:
# ---> 40         stat_result = os.stat(filename)
#      41     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/brainnotation/tpl-fsaverage_den-10k_hemi-L_pial.surf.gii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/vtkmodules/util/vtkAlgorithm.py in ProcessRequest(self, vtkself, request, inInfo, outInfo)
#     150
#     151         def ProcessRequest(self, vtkself, request, inInfo, outInfo):
# --> 152             return vtkself.ProcessRequest(request, inInfo, outInfo)
#     153
#     154     def __init__(self, nInputPorts=1, inputType='vtkDataSet',
#
# ~/.local/lib/python3.8/site-packages/vtkmodules/util/vtkAlgorithm.py in ProcessRequest(self, request, inInfo, outInfo)
#     196             return self.RequestUpdateExtent(request, inInfo, outInfo)
#     197         elif request.Has(vtkDemandDrivenPipeline.REQUEST_DATA()):
# --> 198             return self.RequestData(request, inInfo, outInfo)
#     199
#     200         return 1
#
# ~/.local/lib/python3.8/site-packages/brainspace/vtk_interface/io_support/gifti_support.py in RequestData(self, request, inInfo, outInfo)
#      87     def RequestData(self, request, inInfo, outInfo):
#      88         opt = vtkPolyData.GetData(outInfo, 0)
# ---> 89         s = _read_gifti(self._FileName, self._fnames_pointdata)
#      90         opt.ShallowCopy(s)
#      91         return 1
#
# ~/.local/lib/python3.8/site-packages/brainspace/vtk_interface/io_support/gifti_support.py in _read_gifti(ipth, ipths_pointdata)
#      26
#      27 def _read_gifti(ipth, ipths_pointdata):
# ---> 28     g = nb.load(ipth)
#      29
#      30     points = g.get_arrays_from_intent(INTENT_POINTS)[0].data
#
# ~/.local/lib/python3.8/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      40         stat_result = os.stat(filename)
#      41     except OSError:
# ---> 42         raise FileNotFoundError("No such file or no access: '%s'" % filename)
#      43     if stat_result.st_size <= 0:
#      44         raise ImageFileError("Empty file: '%s'" % filename)
#
# FileNotFoundError: No such file or no access: '/brainnotation/tpl-fsaverage_den-10k_hemi-L_pial.surf.gii'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      39     try:
# ---> 40         stat_result = os.stat(filename)
#      41     except OSError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/brainnotation/tpl-fsaverage_den-10k_hemi-R_pial.surf.gii'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/vtkmodules/util/vtkAlgorithm.py in ProcessRequest(self, vtkself, request, inInfo, outInfo)
#     150
#     151         def ProcessRequest(self, vtkself, request, inInfo, outInfo):
# --> 152             return vtkself.ProcessRequest(request, inInfo, outInfo)
#     153
#     154     def __init__(self, nInputPorts=1, inputType='vtkDataSet',
#
# ~/.local/lib/python3.8/site-packages/vtkmodules/util/vtkAlgorithm.py in ProcessRequest(self, request, inInfo, outInfo)
#     196             return self.RequestUpdateExtent(request, inInfo, outInfo)
#     197         elif request.Has(vtkDemandDrivenPipeline.REQUEST_DATA()):
# --> 198             return self.RequestData(request, inInfo, outInfo)
#     199
#     200         return 1
#
# ~/.local/lib/python3.8/site-packages/brainspace/vtk_interface/io_support/gifti_support.py in RequestData(self, request, inInfo, outInfo)
#      87     def RequestData(self, request, inInfo, outInfo):
#      88         opt = vtkPolyData.GetData(outInfo, 0)
# ---> 89         s = _read_gifti(self._FileName, self._fnames_pointdata)
#      90         opt.ShallowCopy(s)
#      91         return 1
#
# ~/.local/lib/python3.8/site-packages/brainspace/vtk_interface/io_support/gifti_support.py in _read_gifti(ipth, ipths_pointdata)
#      26
#      27 def _read_gifti(ipth, ipths_pointdata):
# ---> 28     g = nb.load(ipth)
#      29
#      30     points = g.get_arrays_from_intent(INTENT_POINTS)[0].data
#
# ~/.local/lib/python3.8/site-packages/nibabel/loadsave.py in load(filename, **kwargs)
#      40         stat_result = os.stat(filename)
#      41     except OSError:
# ---> 42         raise FileNotFoundError("No such file or no access: '%s'" % filename)
#      43     if stat_result.st_size <= 0:
#      44         raise ImageFileError("Empty file: '%s'" % filename)
#
# FileNotFoundError: No such file or no access: '/brainnotation/tpl-fsaverage_den-10k_hemi-R_pial.surf.gii'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ce2764769864> in <module>
#       6
#       7
# ----> 8 surface_plot.plot(np.array(h),'high ISC',None,None,None)
#
# ~/S4B2/data/surface_plot.py in plot(data, title, cmap, view, c_range)
#      16     p = Plot(mesh,mesh2, zoom=1.2, views=view)
#      17
# ---> 18     p.add_layer(data)
#      19     fig = p.build()
#      20     plt.title(title)
#
# ~/.local/lib/python3.8/site-packages/surfplot/plotting.py in add_layer(self, data, cmap, color_range, as_outline, zero_transparent, cbar, cbar_label)
#     333
#     334         if color_range is None:
# --> 335             self.color_ranges.append(_find_color_range(vertices))
#     336         else:
#     337             self.color_ranges.append(color_range)
#
# ~/.local/lib/python3.8/site-packages/surfplot/plotting.py in _find_color_range(v)
#     121         # not necessary to warn the user about this. NaNs won't impact anything
#     122         warnings.filterwarnings('ignore', r'All-NaN (slice|axis) encountered')
# --> 123         vmin = np.nanmin([np.nanmin(v[h]) for h in hemis if h in v])
#     124         vmax = np.nanmax([np.nanmax(v[h]) for h in hemis if h in v])
#     125     return vmin, vmax
#
# ~/.local/lib/python3.8/site-packages/surfplot/plotting.py in <listcomp>(.0)
#     121         # not necessary to warn the user about this. NaNs won't impact anything
#     122         warnings.filterwarnings('ignore', r'All-NaN (slice|axis) encountered')
# --> 123         vmin = np.nanmin([np.nanmin(v[h]) for h in hemis if h in v])
#     124         vmax = np.nanmax([np.nanmax(v[h]) for h in hemis if h in v])
#     125     return vmin, vmax
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# /opt/campux/virtualenv/deeplearning-u20/lib/python3.8/site-packages/numpy/lib/nanfunctions.py in nanmin(a, axis, out, keepdims)
#     319         # Fast, but not safe for subclasses of ndarray, or object arrays,
#     320         # which do not implement isnan (gh-9009), or fmin correctly (gh-8975)
# --> 321         res = np.fmin.reduce(a, axis=axis, out=out, **kwargs)
#     322         if np.isnan(res).any():
#     323             warnings.warn("All-NaN slice encountered", RuntimeWarning,
#
# ValueError: zero-size array to reduction operation fmin which has no identity

# %%
cd
# Out:
# /homes/v20subra
